# %% [markdown]
# # Notebook 4: Topic Modeling (LDA)
#
# Apply Latent Dirichlet Allocation to article abstracts (1988–2020) to identify the 21 topics in academic finance, replicating the paper's approach with Gensim and spaCy.
#
# **Key finding to verify:** No topic relating to group-based inequality or disadvantage emerges.
#
# **Output:** `data/processed/articles_with_topics.parquet`

# %%
import pandas as pd
import numpy as np
import spacy
from gensim.corpora import Dictionary
from gensim.models import LdaMulticore, CoherenceModel
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import os
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Load spaCy model
nlp = spacy.load("en_core_web_sm", disable=["ner", "parser"])

os.makedirs("figures", exist_ok=True)
print("Libraries loaded.")
# Out:
# Libraries loaded.

# %%
# Load articles and filter to those with abstracts (1988-2020)
articles_df = pd.read_parquet("data/processed/articles_gendered.parquet")

lda_articles = articles_df[
    (articles_df["abstract"].notna()) &
    (articles_df["abstract"].str.len() > 50) &
    (articles_df["publication_year"] >= 1988) &
    (articles_df["publication_year"] <= 2020)
].copy().reset_index(drop=True)

print(f"Articles with abstracts (1988-2020): {len(lda_articles):,}")
print(f"Paper reference: 55,210 abstracts")
# Out:
# Articles with abstracts (1988-2020): 47,724
# Paper reference: 55,210 abstracts

# %% [markdown]
# ## 1. Text Preprocessing with spaCy
#
# Lemmatize, remove stopwords, punctuation, numbers, and short tokens.

# %%
def preprocess_text(text: str) -> list[str]:
    """Preprocess a single abstract for LDA."""
    doc = nlp(text)
    tokens = [
        token.lemma_.lower()
        for token in doc
        if not token.is_stop
        and not token.is_punct
        and not token.like_num
        and len(token.text) > 2
        and token.is_alpha
    ]
    return tokens


# Process all abstracts using spaCy's pipe for efficiency
print("Preprocessing abstracts (this may take 20-40 minutes)...")

abstracts = lda_articles["abstract"].tolist()
processed_docs = []

# Process in batches using nlp.pipe
batch_size = 1000
for i in tqdm(range(0, len(abstracts), batch_size), desc="Preprocessing"):
    batch = abstracts[i : i + batch_size]
    for doc in nlp.pipe(batch, batch_size=256):
        tokens = [
            token.lemma_.lower()
            for token in doc
            if not token.is_stop
            and not token.is_punct
            and not token.like_num
            and len(token.text) > 2
            and token.is_alpha
        ]
        processed_docs.append(tokens)

print(f"\nProcessed {len(processed_docs):,} documents")
print(f"Average tokens per document: {np.mean([len(d) for d in processed_docs]):.0f}")
# Out:
# Preprocessing abstracts (this may take 20-40 minutes)...
# Preprocessing:   0%|          | 0/48 [00:00<?, ?it/s]
# Processed 47,724 documents
# Average tokens per document: 78

# %% [markdown]
# ## 2. Build Dictionary and Corpus

# %%
# Build Gensim dictionary
dictionary = Dictionary(processed_docs)
print(f"Dictionary size before filtering: {len(dictionary):,}")

# Filter extremes: remove words in <20 docs or >50% of docs
dictionary.filter_extremes(no_below=20, no_above=0.5)
print(f"Dictionary size after filtering: {len(dictionary):,}")

# Create bag-of-words corpus
corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
print(f"Corpus size: {len(corpus):,} documents")
# Out:
# Dictionary size before filtering: 42,374
# Dictionary size after filtering: 6,026
# Corpus size: 47,724 documents

# %% [markdown]
# ## 3. Train LDA Model (K=21 topics)
#
# The paper identified 21 topics. We train with K=21 to replicate, and also compute coherence scores for a range of K values to validate.

# %%
# Train LDA with K=21 topics
print("Training LDA model with 21 topics...")
lda_model = LdaMulticore(
    corpus=corpus,
    id2word=dictionary,
    num_topics=21,
    random_state=42,
    passes=10,
    workers=3,
    chunksize=2000,
    alpha="asymmetric",
    eta="auto",
)

# Compute coherence
coherence_model = CoherenceModel(
    model=lda_model,
    texts=processed_docs,
    dictionary=dictionary,
    coherence="c_v",
)
coherence_score = coherence_model.get_coherence()
print(f"\nCoherence score (c_v) for K=21: {coherence_score:.4f}")

# Save model
model_dir = "data/processed/lda_model"
os.makedirs(model_dir, exist_ok=True)
lda_model.save(os.path.join(model_dir, "lda_21topics"))
dictionary.save(os.path.join(model_dir, "dictionary"))
print(f"Model saved to {model_dir}/")
# Out:
# Training LDA model with 21 topics...
# Coherence score (c_v) for K=21: 0.4865
# Model saved to data/processed/lda_model/

# %%
# Coherence score sweep to validate K=21
print("Computing coherence for different K values (this takes a while)...")
k_values = list(range(5, 41, 5))
coherence_scores = []

for k in tqdm(k_values, desc="K sweep"):
    model_k = LdaMulticore(
        corpus=corpus, id2word=dictionary, num_topics=k,
        random_state=42, passes=5, workers=3, chunksize=2000,
    )
    cm = CoherenceModel(model=model_k, texts=processed_docs, dictionary=dictionary, coherence="c_v")
    coherence_scores.append(cm.get_coherence())

# Plot
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(k_values, coherence_scores, "bo-")
ax.axvline(x=21, color="red", linestyle="--", label="K=21 (paper)")
ax.set_xlabel("Number of Topics (K)")
ax.set_ylabel("Coherence Score (c_v)")
ax.set_title("Topic Coherence by Number of Topics")
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig("figures/coherence_scores.png", dpi=150, bbox_inches="tight")
plt.show()
print("\nCoherence scores:")
for k, c in zip(k_values, coherence_scores):
    marker = " <-- paper" if k == 20 else ""
    print(f"  K={k:3d}: {c:.4f}{marker}")
# Out:
# Computing coherence for different K values (this takes a while)...
# K sweep:   0%|          | 0/8 [00:00<?, ?it/s]
# Coherence scores:
#   K=  5: 0.4394
#   K= 10: 0.4422
#   K= 15: 0.4585
#   K= 20: 0.4734 <-- paper
#   K= 25: 0.4597
#   K= 30: 0.4599
#   K= 35: 0.4530
#   K= 40: 0.4499

# %% [markdown]
# ## 4. Examine Topics and Check for Inequality Topic

# %%
# Display top words for each topic
print("=" * 80)
print("TOP 15 WORDS PER TOPIC")
print("=" * 80)

inequality_terms = {
    "gender", "sex", "female", "male", "woman", "women", "girl", "boy",
    "discrimination", "inequality", "diversity", "bias", "minority",
    "race", "racial", "ethnic", "disadvantage", "marginali", "exclusion",
    "stereotype", "prejudice",
}

has_inequality_topic = False

for topic_id in range(lda_model.num_topics):
    top_words = lda_model.show_topic(topic_id, topn=15)
    words_str = ", ".join([f"{word} ({prob:.3f})" for word, prob in top_words])
    
    # Check for inequality-related terms
    topic_words = {w for w, _ in top_words}
    overlap = topic_words & inequality_terms
    flag = " *** INEQUALITY-RELATED ***" if overlap else ""
    if overlap:
        has_inequality_topic = True
    
    print(f"\nTopic {topic_id:2d}{flag}:")
    print(f"  {words_str}")

print("\n" + "=" * 80)
if has_inequality_topic:
    print("WARNING: Found topic(s) with inequality-related terms.")
else:
    print("CONFIRMED: No topic relating to group-based inequality was identified.")
    print("This matches the paper's key finding.")
print("=" * 80)
# Out:
# ================================================================================
# TOP 15 WORDS PER TOPIC
# ================================================================================
#
# Topic  0:
#   corporate (0.020), firm (0.019), company (0.017), governance (0.015), study (0.014), board (0.012), management (0.011), performance (0.010), disclosure (0.009), control (0.008), fraud (0.008), finding (0.008), originality (0.008), value (0.008), ceo (0.008)
#
# Topic  1:
#   firm (0.072), debt (0.031), capital (0.027), cost (0.025), tax (0.024), investment (0.018), increase (0.012), financing (0.012), high (0.011), leverage (0.010), structure (0.010), effect (0.009), equity (0.009), find (0.009), abstract (0.008)
#
# Topic  2:
#   cash (0.101), flow (0.084), money (0.026), payment (0.024), access (0.020), content (0.018), value (0.018), available (0.017), provide (0.017), project (0.017), discount (0.016), holding (0.015), abstract (0.014), free (0.012), use (0.012)
#
# Topic  3:
#   option (0.051), model (0.032), price (0.026), volatility (0.016), pricing (0.014), process (0.012), value (0.010), time (0.010), stochastic (0.009), rate (0.008), method (0.008), jump (0.008), derivative (0.008), problem (0.007), function (0.007)
#
# Topic  4:
#   market (0.029), test (0.021), price (0.019), future (0.014), model (0.014), oil (0.013), long (0.013), result (0.012), period (0.012), volatility (0.012), time (0.011), study (0.009), evidence (0.008), commodity (0.008), series (0.008)
#
# Topic  5:
#   study (0.035), result (0.016), financial (0.016), relationship (0.015), effect (0.014), datum (0.013), impact (0.012), variable (0.011), firm (0.011), finding (0.011), performance (0.011), significant (0.010), level (0.009), capital (0.008), growth (0.008)
#
# Topic  6:
#   stock (0.079), market (0.069), return (0.052), volatility (0.032), index (0.023), effect (0.017), price (0.017), investor (0.013), find (0.012), result (0.011), study (0.010), period (0.010), high (0.009), examine (0.008), evidence (0.007)
#
# Topic  7:
#   risk (0.151), portfolio (0.046), asset (0.026), insurance (0.014), measure (0.012), management (0.012), premium (0.011), exposure (0.011), hedge (0.011), factor (0.011), investor (0.010), return (0.010), islamic (0.009), value (0.009), diversification (0.009)
#
# Topic  8:
#   bond (0.086), credit (0.083), default (0.042), rating (0.036), spread (0.036), yield (0.033), risk (0.019), rate (0.016), term (0.016), corporate (0.014), sovereign (0.014), income (0.012), swap (0.012), treasury (0.012), maturity (0.011)
#
# Topic  9:
#   rate (0.073), policy (0.033), exchange (0.026), interest (0.023), inflation (0.023), monetary (0.023), real (0.022), growth (0.017), economic (0.014), model (0.012), economy (0.012), shock (0.011), run (0.011), effect (0.010), macroeconomic (0.009)
#
# Topic 10:
#   bank (0.076), financial (0.043), banking (0.021), crisis (0.020), market (0.015), system (0.013), paper (0.009), sector (0.008), regulation (0.008), institution (0.008), regulatory (0.007), capital (0.007), policy (0.007), development (0.007), country (0.007)
#
# Topic 11:
#   information (0.055), earning (0.049), forecast (0.040), link (0.024), analyst (0.021), accounting (0.018), value (0.015), future (0.011), report (0.010), predict (0.010), measure (0.009), result (0.009), investor (0.008), company (0.008), market (0.007)
#
# Topic 12:
#   price (0.023), demand (0.016), consumption (0.016), household (0.016), model (0.015), income (0.014), asset (0.013), market (0.013), mortgage (0.013), loan (0.012), housing (0.012), agent (0.011), increase (0.010), wealth (0.010), equilibrium (0.008)
#
# Topic 13:
#   financial (0.024), investment (0.022), social (0.017), decision (0.015), pension (0.013), investor (0.013), service (0.012), individual (0.012), student (0.008), environmental (0.008), business (0.008), plan (0.008), product (0.007), benefit (0.007), education (0.007)
#
# Topic 14:
#   market (0.052), trading (0.051), trade (0.035), liquidity (0.029), price (0.026), cost (0.018), order (0.018), transaction (0.015), exchange (0.015), trader (0.015), spread (0.011), information (0.011), volume (0.010), increase (0.007), limit (0.007)
#
# Topic 15:
#   firm (0.045), dividend (0.026), stock (0.023), return (0.020), announcement (0.019), find (0.015), market (0.014), share (0.014), abnormal (0.013), investor (0.013), price (0.011), result (0.010), high (0.010), effect (0.010), examine (0.009)
#
# Topic 16:
#   university (0.040), journal (0.039), financial (0.033), publish (0.023), article (0.022), author (0.022), press (0.021), issue (0.021), reserve (0.019), oxford (0.018), federal (0.014), search (0.013), scholar (0.013), volume (0.013), finance (0.013)
#
# Topic 17:
#   paper (0.032), approach (0.024), purpose (0.023), research (0.019), methodology (0.017), design (0.015), value (0.014), implication (0.013), author (0.011), analysis (0.010), finding (0.009), practical (0.008), provide (0.008), financial (0.008), literature (0.007)
#
# Topic 18:
#   model (0.074), estimate (0.018), distribution (0.014), method (0.014), factor (0.012), return (0.011), base (0.011), datum (0.010), test (0.010), propose (0.010), time (0.009), result (0.009), sample (0.008), approach (0.008), estimation (0.008)
#
# Topic 19:
#   fund (0.071), performance (0.036), portfolio (0.029), return (0.024), investment (0.024), strategy (0.024), manager (0.019), investor (0.019), equity (0.016), mutual (0.013), asset (0.012), market (0.011), management (0.008), author (0.008), index (0.008)
#
# Topic 20:
#   country (0.067), foreign (0.030), international (0.020), market (0.019), economic (0.017), emerge (0.015), growth (0.015), effect (0.014), global (0.014), trade (0.014), china (0.014), domestic (0.013), investment (0.012), develop (0.012), industry (0.011)
#
# ================================================================================
# CONFIRMED: No topic relating to group-based inequality was identified.
# This matches the paper's key finding.
# ================================================================================

# %%
# Generate word clouds for all topics
fig, axes = plt.subplots(3, 7, figsize=(28, 12))
axes = axes.flatten()

for topic_id in range(21):
    topic_words = dict(lda_model.show_topic(topic_id, topn=50))
    wc = WordCloud(
        width=400, height=300, background_color="white",
        colormap="viridis", max_words=50,
    ).generate_from_frequencies(topic_words)
    
    axes[topic_id].imshow(wc, interpolation="bilinear")
    axes[topic_id].set_title(f"Topic {topic_id}", fontsize=10)
    axes[topic_id].axis("off")

plt.suptitle("Word Clouds for 21 LDA Topics in Academic Finance", fontsize=14, y=1.02)
plt.tight_layout()
plt.savefig("figures/topic_wordclouds.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 5. Assign Dominant Topic to Each Article and Save

# %%
# Assign dominant topic to each article
dominant_topics = []
topic_distributions = []

for i, bow in enumerate(tqdm(corpus, desc="Assigning topics")):
    topic_dist = lda_model.get_document_topics(bow, minimum_probability=0.0)
    # Sort by probability to get dominant topic
    topic_dist_sorted = sorted(topic_dist, key=lambda x: x[1], reverse=True)
    dominant_topic = topic_dist_sorted[0][0]
    dominant_prob = topic_dist_sorted[0][1]
    
    dominant_topics.append({
        "dominant_topic": dominant_topic,
        "topic_probability": dominant_prob,
    })
    
    # Store full distribution for later analysis
    topic_distributions.append([prob for _, prob in sorted(topic_dist)])

# Add to dataframe
lda_articles["dominant_topic"] = [d["dominant_topic"] for d in dominant_topics]
lda_articles["topic_probability"] = [d["topic_probability"] for d in dominant_topics]

# Save
lda_articles.to_parquet("data/processed/articles_with_topics.parquet", index=False)

print(f"\nSaved articles with topics: {len(lda_articles):,}")
print(f"\nTopic distribution:")
print(lda_articles["dominant_topic"].value_counts().sort_index())
# Out:
# Assigning topics:   0%|          | 0/47724 [00:00<?, ?it/s]
# Saved articles with topics: 47,724
#
# Topic distribution:
# dominant_topic
# 0     3032
# 1     2617
# 2      482
# 3     3203
# 4     2331
# 5     2912
# 6     3866
# 7     2010
# 8      857
# 9     2872
# 10    3302
# 11    1013
# 12    1334
# 13    1154
# 14    2221
# 15    3018
# 16    1690
# 17    2908
# 18    3201
# 19    2582
# 20    1119
# Name: count, dtype: int64
